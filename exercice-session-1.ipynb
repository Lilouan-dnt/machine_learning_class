# %%
# initialisation
import numpy as np
rng = np.random.default_rng()

# %%
def questionb(a,b): # 1.b écrire la somme suivante en tant qu'opération matricielle
    return np.dot(a,b)

# %%
def questionc(a,b):
    y = a @ b
    return y

# %%
def questiond(x,a):
    y = X @ a
    return y

# %%
def questionf(Z, X):
    y = Z @ X
    return y

# %%
def questiong(X, W, a):
    v = X @ W.T
    y = v @ a
    return y

# %%
#vectors
a = np.arange(0, 5)  # a = [0, 1, 2, 3, 4] 
b = np.arange(5, 10) # b = [5, 6, 7, 8, 9]
#matrix
Z = np.array([[1 ,1], [0, 1]]) 

# creating a dataset
N = 5 #samples
n = 5 #features
P = 5 #set of parameters
X = np.random.randint(0, 10, size=(N, n))
W = np.random.randint(0, 10, size=(P, n))
# creating parameters
a = np.random.randint(0, 10, size=(P))

questiong(X,W,a)
# Out:
# array([1937, 1880, 1163, 1414, 1911])
